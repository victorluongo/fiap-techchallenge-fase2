# %% [markdown]
# <a href="https://colab.research.google.com/github/victorluongo/fiap-techchallenge-fase2/blob/main/tech_challenge_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problema da Mochila com Algoritmo Genético
#
# ## Introdução
#
# O problema da mochila é um clássico em otimização, onde o objetivo é maximizar o valor total de itens que podem ser colocados em uma mochila, respeitando um limite de peso. Neste notebook, vamos explorar uma implementação do algoritmo genético para resolver esse problema.
#
# ## Estrutura do Código
#
# O código é dividido em várias partes, cada uma com uma função específica. Vamos analisar cada uma delas.
#
# ### 1. Importação de Bibliotecas

# %%
import random
import numpy as np
import sys

# %% [markdown]
# Aqui, importamos as bibliotecas necessárias `random` e `numpy` são utilizados para operações aleatórias e numéricas.
#
# ### 2.1. Definição de Parâmetros - P3

# %%
pesos = [56,59,80,64,75,17]
valores = [50, 50, 64, 46, 50, 5]
capacidade_maxima = 190
N_ITENS = len(pesos)

tamanho_populacao = 20
taxa_mutacao = 0.2
numero_geracoes = 1000

# %% [markdown]
# Aqui, definimos os pesos e valores dos itens, a capacidade máxima da mochila e o número total de itens.
#
# ### 2.2. Definição de Parâmetros - P8

# %%
pesos = [382745,799601,909247,729069,467902,44328,34610,698150,823460,903959,853665,551830,610856,670702,488960,951111,323046,446298,931161,31385,496951,264724,224916,169684]
valores = [825594,1677009,1676628,1523970,943972,97426,69666,1296457,1679693,1902996,1844992,1049289,1252836,1319836,953277,2067538,675367,853655,1826027,65731,901489,577243,466257,369261]
capacidade_maxima = 6404180
N_ITENS = len(pesos)

tamanho_populacao = 20
taxa_mutacao = 0.2
numero_geracoes = 1000

# %% [markdown]
# Aqui, definimos os pesos e valores dos itens, a capacidade máxima da mochila e o número total de itens.

# %% [markdown]
# ### 3. Funções do Algoritmo Genético
#
# #### Função de Aptidão

# %%
def funcao_aptidao(individuo):
  peso_total = sum([pesos[i] for i in range(len(individuo)) if individuo[i] == 1])
  valor_total = sum([valores[i] for i in range(len(individuo)) if individuo[i] == 1])
  if peso_total > capacidade_maxima:
    return 0
  return valor_total

# %% [markdown]
# Esta função calcula a aptidão de um indivíduo (solução) com base no peso e valor total dos itens selecionados.
#
# #### Geração da População Inicial

# %%
def gerar_populacao_inicial(tamanho_populacao, numero_itens):
    populacao = []
    for _ in range(tamanho_populacao):
        individuo = [random.randint(0, 1) for _ in range(numero_itens)]
        if random.random() < 0.3:
            individuo = [0] * numero_itens
            peso_atual = 0
            for i in sorted(range(numero_itens), key=lambda x: valores[x] / pesos[x], reverse=True):
                if peso_atual + pesos[i] <= capacidade_maxima:
                    individuo[i] = 1
                    peso_atual += pesos[i]
        populacao.append(individuo)
    return populacao

# %% [markdown]
# Aqui, geramos uma população inicial de indivíduos aleatórios.
#
# #### Seleção

# %%
def selecao(populacao, aptidoes):
    total_aptidao = sum(aptidoes)
    if total_aptidao == 0:
        return random.choice(populacao)
    pick = random.uniform(0, total_aptidao)
    current = 0
    for i, individuo in enumerate(populacao):
        current += aptidoes[i]
        if current > pick:
            return individuo

# %% [markdown]
# A seleção é feita com base na aptidão dos indivíduos, onde indivíduos mais aptos têm maior chance de serem escolhidos.
#
# #### Cruzamento e Mutação

# %%
def cruzamento(pai1, pai2):
    pontos_corte = sorted(random.sample(range(1, len(pai1)), 2))
    filho1 = pai1[:pontos_corte[0]] + pai2[pontos_corte[0]:pontos_corte[1]] + pai1[pontos_corte[1]:]
    filho2 = pai2[:pontos_corte[0]] + pai1[pontos_corte[0]:pontos_corte[1]] + pai2[pontos_corte[1]:]
    return filho1, filho2

def mutacao(individuo, taxa_mutacao):
    for i in range(len(individuo)):
        if random.random() < taxa_mutacao:
            individuo[i] = 1 - individuo[i]
    return individuo

# %% [markdown]
# ### 4. Execução do Algoritmo Genético

# %%
def algoritmo_genetico():
    populacao = gerar_populacao_inicial(tamanho_populacao, N_ITENS)
    best_fitness_values = []

    for geracao in range(numero_geracoes):
        aptidoes = [funcao_aptidao(individuo) for individuo in populacao]
        nova_populacao = []
        melhor_individuo = populacao[aptidoes.index(max(aptidoes))]
        nova_populacao.append(melhor_individuo)
        taxa_mutacao_geracao = taxa_mutacao * (1 - geracao / numero_geracoes)

        while len(nova_populacao) < tamanho_populacao:
            pai1 = selecao(populacao, aptidoes)
            pai2 = selecao(populacao, aptidoes)
            filho1, filho2 = cruzamento(pai1, pai2)
            nova_populacao.append(mutacao(filho1, taxa_mutacao_geracao))
            if len(nova_populacao) < tamanho_populacao:
                nova_populacao.append(mutacao(filho2, taxa_mutacao_geracao))

        populacao = nova_populacao
        best_fitness = max(aptidoes)
        best_fitness_values.append(best_fitness)
        best_individuo = populacao[aptidoes.index(best_fitness)]
        capacidade_usada = sum([pesos[i] for i in range(len(best_individuo)) if best_individuo[i] == 1])
        print(f"Geração {geracao + 1}: Melhor valor = {best_fitness}, Melhor indivíduo = {best_individuo}, Capacidade usada = {capacidade_usada}/{capacidade_maxima}")

    melhor_individuo = populacao[aptidoes.index(max(aptidoes))]
    print('Melhor solução encontrada:', melhor_individuo)
    print('Valor total:', funcao_aptidao(melhor_individuo))
    capacidade_usada = sum([pesos[i] for i in range(len(melhor_individuo)) if melhor_individuo[i] == 1])
    print(f'Capacidade total usada: {capacidade_usada}/{capacidade_maxima}')

    return melhor_individuo, funcao_aptidao(melhor_individuo), capacidade_usada

solucao_genetico, valor_total_genetico, capacidade_usada_genetico = algoritmo_genetico()
# Out:
# Geração 1: Melhor valor = 146, Melhor indivíduo = [1, 0, 1, 0, 0, 0], Capacidade usada = 136/190
# Geração 2: Melhor valor = 146, Melhor indivíduo = [1, 1, 0, 1, 0, 0], Capacidade usada = 179/190
# Geração 3: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 1, 1, 1], Capacidade usada = 271/190
# Geração 4: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 5: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 6: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 7: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 8: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 9: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 10: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 11: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 12: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 13: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 14: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 15: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 16: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 17: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 18: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 19: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 20: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 21: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 22: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 23: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 24: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 25: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 26: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 27: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 28: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 29: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 30: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 31: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 32: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 33: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 34: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 35: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 36: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 37: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 38: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 39: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 40: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 41: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 42: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 43: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 44: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 45: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 46: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 47: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 48: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 49: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 50: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 51: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 52: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 53: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 54: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 55: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 56: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 57: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 58: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 59: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 60: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 61: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 62: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 63: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 64: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 65: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 66: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 67: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 68: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 69: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 70: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 71: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 72: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 73: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 74: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 75: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 76: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 77: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 78: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 79: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 80: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 81: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 82: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 83: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 84: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 85: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 86: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 87: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 88: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 89: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 90: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 91: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 92: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 93: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 94: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 95: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 96: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 97: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 98: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 99: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 100: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 101: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 102: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 103: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 104: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 105: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 106: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 107: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 108: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 109: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 110: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 111: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 112: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 113: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 114: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 115: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 116: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 117: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 118: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 119: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 120: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 121: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 122: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 123: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 124: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 125: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 126: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 127: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 128: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 129: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 130: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 131: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 132: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 133: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 134: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 135: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 136: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 137: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 138: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 139: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 140: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 141: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 142: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 143: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 144: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 145: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 146: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 147: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 148: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 149: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 150: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 151: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 152: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 153: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 154: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 155: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 156: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 157: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 158: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 159: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 160: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 161: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 162: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 163: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 164: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 165: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 166: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 167: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 168: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 169: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 170: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 171: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 172: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 173: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 174: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 175: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 176: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 177: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 178: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 179: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 180: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 181: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 182: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 183: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 184: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 185: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 186: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 187: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 188: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 189: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 190: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 191: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 192: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 193: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 194: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 195: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 196: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 197: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 198: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 199: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 200: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 201: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 202: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 203: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 204: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 205: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 206: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 207: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 208: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 209: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 210: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 211: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 212: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 213: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 214: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 215: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 216: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 217: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 218: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 219: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 220: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 221: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 222: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 223: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 224: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 225: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 226: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 227: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 228: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 229: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 230: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 231: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 232: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 233: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 234: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 235: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 236: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 237: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 238: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 239: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 240: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 241: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 242: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 243: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 244: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 245: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 246: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 247: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 248: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 249: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 250: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 251: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 252: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 253: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 254: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 255: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 256: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 257: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 258: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 259: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 260: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 261: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 262: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 263: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 264: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 265: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 266: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 267: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 268: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 269: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 270: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 271: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 272: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 273: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 274: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 275: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 276: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 277: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 278: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 279: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 280: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 281: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 282: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 283: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 284: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 285: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 286: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 287: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 288: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 289: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 290: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 291: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 292: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 293: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 294: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 295: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 296: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 297: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 298: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 299: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 300: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 301: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 302: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 303: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 304: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 305: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 306: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 307: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 308: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 309: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 310: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 311: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 312: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 313: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 314: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 315: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 316: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 317: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 318: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 319: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 320: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 321: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 322: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 323: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 324: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 325: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 326: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 327: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 328: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 329: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 330: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 331: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 332: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 333: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 334: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 335: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 336: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 337: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 338: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 339: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 340: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 341: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 342: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 343: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 344: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 345: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 346: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 347: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 348: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 349: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 350: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 351: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 352: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 353: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 354: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 355: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 356: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 357: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 358: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 359: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 360: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 361: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 362: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 363: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 364: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 365: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 366: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 367: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 368: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 369: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 370: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 371: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 372: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 373: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 374: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 375: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 376: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 377: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 378: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 379: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 380: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 381: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 382: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 383: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 384: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 385: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 386: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 387: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 388: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 389: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 390: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 391: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 392: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 393: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 394: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 395: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 396: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 397: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 398: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 399: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 400: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 401: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 402: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 403: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 404: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 405: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 406: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 407: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 408: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 409: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 410: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 411: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 412: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 413: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 414: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 415: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 416: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 417: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 418: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 419: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 420: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 421: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 422: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 423: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 424: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 425: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 426: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 427: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 428: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 429: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 430: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 431: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 432: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 433: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 434: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 435: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 436: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 437: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 438: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 439: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 440: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 441: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 442: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 443: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 444: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 445: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 446: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 447: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 448: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 449: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 450: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 451: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 452: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 453: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 454: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 455: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 456: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 457: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 458: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 459: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 460: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 461: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 462: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 463: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 464: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 465: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 466: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 467: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 468: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 469: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 470: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 471: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 472: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 473: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 474: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 475: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 476: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 477: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 478: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 479: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 480: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 481: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 482: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 483: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 484: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 485: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# ...
# Geração 841: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 842: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 843: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 844: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 845: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 846: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 847: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 848: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 849: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 850: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 851: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 852: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 853: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 854: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 855: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 856: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 857: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 858: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 859: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 860: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 861: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 862: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 863: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 864: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 865: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 866: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 867: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 868: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 869: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 870: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 871: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 872: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 873: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 874: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 875: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 876: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 877: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 878: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 879: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 880: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 881: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 882: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 883: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 884: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 885: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 886: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 887: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 888: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 889: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 890: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 891: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 892: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 893: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 894: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 895: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 896: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 897: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 898: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 899: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 900: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 901: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 902: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 903: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 904: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 905: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 906: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 907: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 908: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 909: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 910: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 911: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 912: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 913: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 914: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 915: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 916: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 917: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 918: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 919: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 920: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 921: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 922: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 923: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 924: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 925: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 926: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 927: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 928: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 929: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 930: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 931: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 932: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 933: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 934: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 935: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 936: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 937: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 938: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 939: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 940: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 941: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 942: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 943: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 944: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 945: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 946: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 947: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 948: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 949: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 950: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 951: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 952: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 953: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 954: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 955: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 956: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 957: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 958: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 959: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 960: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 961: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 962: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 963: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 964: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 965: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 966: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 967: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 968: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 969: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 970: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 971: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 972: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 973: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 974: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 975: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 976: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 977: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 978: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 979: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 980: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 981: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 982: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 983: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 984: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 985: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 986: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 987: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 988: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 989: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 990: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 991: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 992: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 993: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 994: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 995: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 996: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 997: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 998: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 999: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Geração 1000: Melhor valor = 150, Melhor indivíduo = [1, 1, 0, 0, 1, 0], Capacidade usada = 190/190
# Melhor solução encontrada: [1, 1, 0, 0, 1, 0]
# Valor total: 150
# Capacidade total usada: 190/190

# %% [markdown]
# ### 5. Execução do algoritmo guloso

# %%
def algoritmo_guloso(pesos, valores, capacidade_maxima):
    numero_itens = len(pesos)
    itens = list(range(numero_itens))

    razao = [valores[i] / pesos[i] for i in itens]
    itens_ordenados = sorted(itens, key=lambda i: razao[i], reverse=True)

    capacidade_atual = 0
    valor_total = 0
    solucao = [0] * numero_itens

    for i in itens_ordenados:
        if capacidade_atual + pesos[i] <= capacidade_maxima:
            solucao[i] = 1
            capacidade_atual += pesos[i]
            valor_total += valores[i]
        else:
            continue

    print(f"Solução Gulosa: {solucao}")
    print(f"Valor Total: {valor_total}")
    print(f"Capacidade Usada: {capacidade_atual}/{capacidade_maxima}")


    return solucao, valor_total, capacidade_atual

solucao_gulosa, valor_total_gulosa, capacidade_usada_gulosa = algoritmo_guloso(pesos, valores, capacidade_maxima)
# Out:
# Solução Gulosa: [1, 1, 0, 1, 0, 0]
# Valor Total: 146
# Capacidade Usada: 179/190

# %% [markdown]
# ### 6. Comparação do resultado

# %%
from tabulate import tabulate

gap_absoluto_1 = valor_total_genetico - valor_total_gulosa
gap_percentual_1 = (gap_absoluto_1 / valor_total_genetico) * 100

gap_absoluto_2 = valor_total_gulosa - valor_total_genetico
gap_percentual_2 = (gap_absoluto_2 / valor_total_gulosa) * 100


tabela = [
    ["Algoritmo Genetico", capacidade_usada_genetico, capacidade_maxima, valor_total_genetico, gap_absoluto_1, f"{gap_percentual_1:.2f}%", solucao_genetico],
    ["Algoritmo Guloso", capacidade_usada_gulosa, capacidade_maxima, valor_total_gulosa, gap_absoluto_2, f"{gap_percentual_2:.2f}%", solucao_gulosa]
]

cabecalho = ["Conjunto", "Capacidade Usada", "Capacidade Máxima", "Valor Total", "GAP Absoluto de Valor", "GAP Percentual Valor", "Solução"]
colalign = ["left", "right", "right", "right", "right", "right", "right"]

print(tabulate(tabela, headers=cabecalho, tablefmt="grid", colalign=colalign))
# Out:
# +--------------------+--------------------+---------------------+---------------+-------------------------+------------------------+--------------------+
# | Conjunto           |   Capacidade Usada |   Capacidade Máxima |   Valor Total |   GAP Absoluto de Valor |   GAP Percentual Valor |            Solução |
# +====================+====================+=====================+===============+=========================+========================+====================+
# | Algoritmo Genetico |                190 |                 190 |           150 |                       4 |                  2.67% | [1, 1, 0, 0, 1, 0] |
# +--------------------+--------------------+---------------------+---------------+-------------------------+------------------------+--------------------+
# | Algoritmo Guloso   |                179 |                 190 |           146 |                      -4 |                 -2.74% | [1, 1, 0, 1, 0, 0] |
# +--------------------+--------------------+---------------------+---------------+-------------------------+------------------------+--------------------+
